# %%
# ( Si Colab est utilisé ), il faut installer la librairie Levenshtein
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Obtaining dependency information for python-Levenshtein from https://files.pythonhosted.org/packages/c9/79/eaa5f632f10be7b9ff85673be2246926e5a6a83fc489a228a22a95b5dcf0/python_Levenshtein-0.25.0-py3-none-any.whl.metadata
#   Downloading python_Levenshtein-0.25.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.25.0 (from python-Levenshtein)
#   Obtaining dependency information for Levenshtein==0.25.0 from https://files.pythonhosted.org/packages/5c/33/c02ace28117403e8906bfb030d5295dd61f23e11ff05f72b34b16e82cf8f/Levenshtein-0.25.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Levenshtein-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in c:\users\taoze\miniconda3\envs\devoir\lib\site-packages (from Levenshtein==0.25.0->python-Levenshtein) (3.5.2)
# Downloading python_Levenshtein-0.25.0-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.0-cp311-cp311-win_amd64.whl (98 kB)
#    ---------------------------------------- 0.0/98.5 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/98.5 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 98.5/98.5 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: Levenshtein, python-Levenshtein
#   Attempting uninstall: Levenshtein
#     Found existing installation: Levenshtein 0.23.0
#     Uninstalling Levenshtein-0.23.0:
#       Successfully uninstalled Levenshtein-0.23.0
# Successfully installed Levenshtein-0.25.0 python-Levenshtein-0.25.0

# %%
import os
import pandas as pd
import numpy as np
import Levenshtein

# %%
# ( Si Colab est utilisé )
from google.colab import drive
drive.mount('/content/drive')

# %%
# ( Si Colab est utilisé ) Mettre le chemin du drive du dossier 'Projet'
os.chdir('/content/drive/.../IFT3700-Partie 1')

# %%
# Ce dossier a été nettoyé manuellement pour enlever des éléments dans certains fichiers. 
# Par exemple: 
# fichier 10: (details)
# fichier 11: les valeurs comme 0.5-1.0 sont remplacées par 0.75, la moyenne
# fichier 27: (OPEC)
# fichier 31: [Note]
# fichier 33: (more info)
# etc. ...
dossier_brutes = 'Données brutes'

# %%
# Nettoyage des données brutes
# Les lignes contenant des valeurs vides, manquantes, des % et des < ont été supprimées
# Certains noms de pays ont été aussi changés pour correspondre au nom des pays dans le fichier countries of the world
for fichier in os.listdir(dossier_brutes):
    if fichier.endswith('.csv'):
        chemin_complet = os.path.join(dossier_brutes, fichier)
        
        # Lire le fichier CSV
        df = pd.read_csv(chemin_complet)
        
        # Vérifier que la deuxième colonne existe
        if df.shape[1] >= 2:
                                

            # Traiter chaque ligne
            supprimer_lignes = []
            for index in range(len(df)):

                cell_value = df.iloc[index, 1]
                # Vérifier si la deuxième colonne est vide 
                if pd.isna(cell_value):
                    supprimer_lignes.append(index)
                    continue  
                
                str_cell_value = str(cell_value)
                if str_cell_value== '—' or str_cell_value=='–' or str_cell_value=='-':
                    supprimer_lignes.append(index)
                    continue

                if str_cell_value == 'n.a.':
                    supprimer_lignes.append(index)
                    continue        
                
                if isinstance(cell_value, str):
                    df.iloc[index, 1] = cell_value.replace(',', '')
                    
                cell_value = df.iloc[index, 1]
                str_cell_value = str(cell_value)
                if str_cell_value.strip().startswith('<'):
                    df.iloc[index, 1] = str_cell_value.replace('< ', '')
                    
                cell_value = df.iloc[index, 1]
                str_cell_value = str(cell_value)
                if str_cell_value.strip().endswith('%'):
                    df.iloc[index, 1] = str_cell_value.rstrip('%')

                    
            df = df.drop(supprimer_lignes)
            # Enregistrer les modifications
            
            nouveau_chemin = os.path.join('Données nettoyées', fichier)
            df.to_csv(nouveau_chemin, index=False)
            
            for index in range(len(df)):
                cell_value = df.iloc[index, 0]
                if str(cell_value) == 'DR Congo' or str(cell_value) == 'Congo DR' or str(cell_value) == 'Congo, Democratic Republic of':    
                    df.iloc[index, 0] = 'Democratic Republic of the Congo'
                if str(cell_value) == 'Congo, Republic of':    
                    df.iloc[index, 0] = 'Republic of the Congo'    
                if str(cell_value) == 'Saint Helena, Ascension and Tristan da Cunha' or str(cell_value) == 'Saint Helena, Ascension, and Tristan da Cunha':  
                    df.iloc[index, 0] = 'Saint Helena'
                
            df.to_csv(nouveau_chemin, index=False)

# %%
# Calculer les statistiques 

dossier_nettoyé = 'Données nettoyées'
fichiers = os.listdir(dossier_nettoyé)
fichiers.sort()

stats_list = []	
for filename in fichiers:
    if filename.endswith('.csv'):
        chemin_complet = os.path.join(dossier_nettoyé, filename)
        # Lire le fichier CSV
        df = pd.read_csv(chemin_complet)

        # Calculer les statistiques pour la deuxième colonne
        column = df.iloc[1:, 1]  # La deuxième colonne
        stats_dict = {
            'filename': filename,
            'mean': column.mean(),
            'median': column.median(),
            'mode': column.mode()[0],
            'max': column.max(),
            'min': column.min(),
            'variance': column.var()
        }
        print(stats_dict)
        # Ajouter le dictionnaire à la liste
        stats_list.append(stats_dict)
# Out:
# {'filename': '01. List_of_countries_by_GDP_(nominal)_per_capita_1.csv', 'mean': 17501.37089201878, 'median': 6785.0, 'mode': 302, 'max': 169260, 'min': 302, 'variance': 627759879.5551866}
# {'filename': '02. List_of_sovereign_states_by_Internet_connection_speeds_1.csv', 'mean': 103.35610000000001, 'median': 86.45, 'mode': 77.88, 'max': 265.17, 'min': 35.32, 'variance': 3661.565100797978}
# {'filename': '03. List_of_countries_by_alcohol_consumption_per_capita_1.csv', 'mean': 6.205851063829786, 'median': 6.3, 'mode': 4.8, 'max': 15.2, 'min': 0.0, 'variance': 16.679377346683353}
# {'filename': '04. List_of_countries_by_intentional_homicide_rate_2.csv', 'mean': 6.622926829268292, 'median': 2.6, 'mode': 1.1, 'max': 52.1, 'min': 0.0, 'variance': 92.48148158775706}
# {'filename': '05. List_of_countries_with_highest_military_expenditures_1.csv', 'mean': 3.2350000000000003, 'median': 1.85, 'mode': 1.2, 'max': 34.0, 'min': 0.6, 'variance': 27.502333333333336}
# {'filename': '06. List_of_countries_by_Human_Development_Index_2.csv', 'mean': 0.7193052631578948, 'median': 0.735, 'mode': 0.745, 'max': 0.961, 'min': 0.385, 'variance': 0.02250871055416319}
# {'filename': '07. The_Economist_Democracy_Index_4.csv', 'mean': 5.3464457831325305, 'median': 5.705, 'mode': 1.95, 'max': 9.81, 'min': 1.08, 'variance': 5.012157594012412}
# {'filename': '08. List_of_countries_by_tertiary_education_attainment_2.csv', 'mean': 39.509302325581395, 'median': 41.0, 'mode': 41.0, 'max': 69.0, 'min': 11.0, 'variance': 158.01181616832787}
# {'filename': '09. Importance_of_religion_by_country_1.csv', 'mean': 75.27027027027027, 'median': 84.0, 'mode': 95, 'max': 99, 'min': 16, 'variance': 543.7262899262903}
# {'filename': '10. Christianity_by_country_3.csv', 'mean': 54.51980099502487, 'median': 67.0, 'mode': 1.0, 'max': 100.0, 'min': 0.01, 'variance': 1260.6668809601993}
# {'filename': '11. Islam_by_country_1.csv', 'mean': 23.065151515151513, 'median': 2.6, 'mode': 0.1, 'max': 99.9, 'min': 0.0, 'variance': 1271.8683103030303}
# {'filename': '12. Buddhism_by_country_1.csv', 'mean': 4.643016759776536, 'median': 0.1, 'mode': 0.1, 'max': 97.9, 'min': 0.1, 'variance': 256.0959481514032}
# {'filename': '13. Jewish_population_by_country_1.csv', 'mean': 1.504726534653465, 'median': 0.012, 'mode': 0.00062, 'max': 100.0, 'min': 0.00062, 'variance': 110.24475691750482}
# {'filename': '14. List_of_countries_by_infant_and_under-five_mortality_rates_1.csv', 'mean': 26.600000000000005, 'median': 16.05, 'mode': 2.2, 'max': 114.6, 'min': 1.8, 'variance': 739.8655497382204}
# {'filename': '15. Age_of_criminal_responsibility_1.csv', 'mean': 12.19047619047619, 'median': 13.0, 'mode': 14, 'max': 18, 'min': 0, 'variance': 8.634160250926724}
# {'filename': '16. List_of_countries_by_minimum_wage_1.csv', 'mean': 6219.198227848102, 'median': 2977.5, 'mode': 5850.0, 'max': 34515.0, 'min': 0.0, 'variance': 62217958.249260485}
# {'filename': '17. List_of_countries_by_external_debt_1.csv', 'mean': 78.53612440191387, 'median': 46.0, 'mode': 2.0, 'max': 1368.0, 'min': 0.0, 'variance': 18186.814437311383}
# {'filename': '18. List_of_countries_by_income_equality_1.csv', 'mean': 37.455416666666665, 'median': 36.35, 'mode': 36.0, 'max': 63.0, 'min': 22.71, 'variance': 63.73556988522954}
# {'filename': '19. List_of_countries_by_total_health_expenditure_per_capita_2.csv', 'mean': 1154.2727272727273, 'median': 387.0, 'mode': 41, 'max': 10285, 'min': 18, 'variance': 3436990.694037144}
# {'filename': '20. List_of_countries_by_suicide_rate_1.csv', 'mean': 10.080952380952382, 'median': 8.3, 'mode': 7.2, 'max': 87.5, 'min': 0.3, 'variance': 73.3178267477204}
# {'filename': '21. List_of_countries_by_total_fertility_rate_2.csv', 'mean': 2.4719262295081967, 'median': 2.03, 'mode': 1.6, 'max': 6.31, 'min': 0.77, 'variance': 1.4209308422721443}
# {'filename': '22. Tobacco_consumption_by_country_1.csv', 'mean': 880.3044444444444, 'median': 557.4, 'mode': 9.7, 'max': 6330.9, 'min': 9.7, 'variance': 640436.332494103}
# {'filename': '23. List_of_countries_by_obesity_rate_1.csv', 'mean': 19.695287958115184, 'median': 20.6, 'mode': 20.2, 'max': 55.9, 'min': 2.1, 'variance': 123.5977145219069}
# {'filename': '24. List_of_countries_by_number_of_Internet_users_3.csv', 'mean': 56.882629107981224, 'median': 62.9, 'mode': 7.3, 'max': 102.4, 'min': 1.7, 'variance': 859.144932677828}
# {'filename': '25. List_of_countries_by_median_age_1.csv', 'mean': 31.666666666666668, 'median': 31.65, 'mode': 20.3, 'max': 55.4, 'min': 14.8, 'variance': 81.8149192364171}
# {'filename': '26. List_of_sovereign_states_by_economic_freedom_1.csv', 'mean': 60.601117318435755, 'median': 60.7, 'mode': 55.4, 'max': 89.4, 'min': 5.9, 'variance': 122.41539200301291}
# {'filename': '27. List_of_countries_by_oil_production_2.csv', 'mean': 1539775.268041237, 'median': 61281.0, 'mode': 1000, 'max': 80618895, 'min': 19, 'variance': 68829284454843.12}
# {'filename': '28. List_of_countries_by_population_growth_rate_1.csv', 'mean': 1.2460714285714287, 'median': 1.0950000000000002, 'mode': 0.24, 'max': 4.26, 'min': -1.03, 'variance': 1.1376824358974353}
# {'filename': '29. List_of_countries_by_life_expectancy_3.csv', 'mean': 72.47540983606558, 'median': 73.3, 'mode': 76.0, 'max': 83.4, 'min': 50.7, 'variance': 50.052743649792816}
# {'filename': '30. List_of_countries_by_meat_consumption_1.csv', 'mean': 45.80055248618784, 'median': 35.4, 'mode': 67.4, 'max': 145.9, 'min': 3.0, 'variance': 1217.8333885819525}
# {'filename': '31. List_of_countries_by_incarceration_rate_1.csv', 'mean': 172.4009009009009, 'median': 142.0, 'mode': 103.0, 'max': 1086.0, 'min': 22.0, 'variance': 17881.32723900371}
# {'filename': '32. List_of_countries_by_literacy_rate_1.csv', 'mean': 63.02095808383233, 'median': 69.7, 'mode': 88.1, 'max': 100.0, 'min': 3.7, 'variance': 907.2443171488344}
# {'filename': '33. List_of_countries_by_age_at_first_marriage_1.csv', 'mean': 25.144791666666666, 'median': 25.0, 'mode': 25.0, 'max': 34.8, 'min': 15.5, 'variance': 20.71033922338569}
# {'filename': '34. List_of_countries_by_spending_on_education_as_percentage_of_GDP_1.csv', 'mean': 4.497068062827226, 'median': 4.2, 'mode': 4.0, 'max': 12.9, 'min': 0.6, 'variance': 3.664589253237812}
# {'filename': '35. List_of_sovereign_states_by_homeless_population_1.csv', 'mean': 294.5708333333333, 'median': 35.349999999999994, 'mode': 0.0, 'max': 3753.0, 'min': 0.0, 'variance': 329120.9251932731}
# {'filename': '36. List_of_countries_by_milk_consumption_per_capita_1.csv', 'mean': 109.33894444444444, 'median': 94.21000000000001, 'mode': 2.92, 'max': 349.21, 'min': 2.92, 'variance': 7510.5776061421475}
# {'filename': '37. List_of_countries_by_number_of_scientific_and_technical_journal_articles_1.csv', 'mean': 867.0219298245614, 'median': 268.5, 'mode': 9.0, 'max': 6061.0, 'min': 2.0, 'variance': 1651549.0964332647}
# {'filename': '38. Books_published_per_country_per_year_1.csv', 'mean': 16281.219696969696, 'median': 2079.0, 'mode': 14, 'max': 208418, 'min': 7, 'variance': 1338857066.7528908}
# {'filename': '39. List_of_countries_by_food_energy_intake_1.csv', 'mean': 2864.9764705882353, 'median': 2855.5, 'mode': 3307, 'max': 3782, 'min': 1786, 'variance': 202681.97577445186}
# {'filename': '40. List_of_countries_by_average_yearly_temperature_1.csv', 'mean': 18.675287958115184, 'median': 22.1, 'mode': 27.15, 'max': 28.25, 'min': -5.35, 'variance': 69.06586715348583}

# %%
# Création du Fichier finale

n_cols = 41
n_rows = 238
df = pd.DataFrame(np.nan, index=range(n_rows), columns=range(n_cols))

# Enregistrer le DataFrame dans un fichier CSV
df.to_csv('fichier_finale.csv', index=False)

# %%
# Placer tous les pays qui existent dans le fichier finale.csv à partir du fichier countries of the world.csv

fichier_finale = 'fichier_finale.csv'
countries = 'countries of the world.csv'
df1 = pd.read_csv(countries)
df2 = pd.read_csv(fichier_finale)

colonne = df1['Country']

# Assurez-vous que le nombre de lignes dans les deux DataFrames correspond
df2.rename(columns={'0': 'Country'}, inplace=True)
df2['Country'] = colonne

# Enregistrer le second DataFrame dans un nouveau fichier CSV
df2.to_csv(fichier_finale, index=False)

# %%
#Renommer les colonnes du fichier finale.csv par les nom des colonnes des 40 fichiers


i = 1
for fichier in fichiers:
    df2 = pd.read_csv(fichier_finale)
    if fichier.endswith('.csv'):
        chemin_complet = os.path.join(dossier_nettoyé, fichier)
        df1 = pd.read_csv(chemin_complet)
        colonne = df1.columns[1]
        df2.rename(columns={str(i): colonne}, inplace=True)

        # Lire le fichier CSV

                    
    df2.to_csv(fichier_finale, index=False)    
    i = i + 1

# %%
# Remplir les valeurs du fichier finale.csv par les valeurs des 40 fichiers du dossier Données binarisées
# Utiliser la distance de Levenshtein pour trouver les pays similaires et remplacer les valeurs
# Peux prendre du temps pour s'exécuter (environ 20 secondes)

df2 = pd.read_csv(fichier_finale)
# Parcourir tous les fichiers dans le dossier
i = 1
for fichier in fichiers:
    if fichier.endswith('.csv'):
        chemin_complet = os.path.join(dossier_nettoyé, fichier)
        
        # Lire le fichier CSV
        df1 = pd.read_csv(chemin_complet)

        for index in range(len(df1)):
            # Utiliser .iloc pour accéder à la valeur par position
            cell_pays = df1.iloc[index, 0]
            cell_valeur = df1.iloc[index, 1]
            temp_similarite = 0
            temp_index = 0
            
            for index2 in range(len(df2)):
                cell_pays2 = df2.iloc[index2, 0]
                
                # Comparer les valeurs des cellules
                if Levenshtein.ratio(cell_pays, cell_pays2) > 0.95:
                    df2.iloc[index2, i] = cell_valeur
                    break
                if Levenshtein.ratio(cell_pays, cell_pays2) > 0.74 and Levenshtein.ratio(cell_pays, cell_pays2) > temp_similarite:
                    # Remplacer la valeur de la cellule

                    temp_index = index2
                    temp_similarite = Levenshtein.ratio(cell_pays, cell_pays2)
                    temp_cell_pays = cell_pays
                      
            if temp_similarite> 0.74:
                df2.iloc[temp_index, i] = cell_valeur
    
    i = i + 1    
            # Enregistrer les modifications
    df2.to_csv(fichier_finale, index=False)
